# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import copy
from ofa.utils import AverageMeter, get_net_device, DistributedTensor
from ofa.imagenet_classification.elastic_nn.modules.dynamic_op import DynamicBatchNorm2d
from ofa.imagenet_classification.elastic_nn.networks import OFAResNets
from MemSE import ROOT
from MemSE.dataset import get_dataset, get_transforms, NORM_COEFS, get_dataloader
from MemSE.nn import MemSE, MEMSE_MAP

dataset, num_classes, input_shape = get_dataset('CIFAR10')
transform_train, transform_test = get_transforms(NORM_COEFS.get('ImageNet'))
dataset = dataset(root=f'{ROOT}/data', train=True, download=True, transform=transform_train)
train_loader, train_clean_loader, test_loader, nclasses, input_shape = get_dataloader('CIFAR10')

def evaluate_ofa_subnet(
    ofa_net, path, net_config, data_loader, batch_size, device="cuda:0"
):
    assert "ks" in net_config and "d" in net_config and "e" in net_config
    assert (
        len(net_config["ks"]) == 20
        and len(net_config["e"]) == 20
        and len(net_config["d"]) == 5
    )
    ofa_net.set_active_subnet(ks=net_config["ks"], d=net_config["d"], e=net_config["e"])
    subnet = ofa_net.get_active_subnet().to(device)
    calib_bn(subnet, path, net_config["r"][0], batch_size)
    top1 = validate(subnet, path, net_config["r"][0], data_loader, batch_size, device)
    return top1


def preprocess_ofa_subnet_for_memse(
    ofa_net, dataset, batch_size, input_shape, sigma: float, N: int, device="cuda:0"
):
    ofa_net.sample_active_subnet()
    subnet = ofa_net.get_active_subnet().to(device)
    calib_bn(subnet, dataset, batch_size)
    memse = MemSE(subnet, MEMSE_MAP).to(device)
    return memse, subnet


def calib_bn(net, dataset, batch_size, num_images=2000):
    # print('Creating dataloader for resetting BN running statistics...')
    chosen_indexes = np.random.choice(list(range(len(dataset))), num_images)
    sub_sampler = torch.utils.data.sampler.SubsetRandomSampler(chosen_indexes)
    data_loader = torch.utils.data.DataLoader(
        dataset,
        sampler=sub_sampler,
        batch_size=batch_size,
        num_workers=16,
        pin_memory=True,
        drop_last=False,
    )
    # print('Resetting BN running statistics (this may take 10-20 seconds)...')
    set_running_statistics(net, data_loader)
    
    
def set_running_statistics(model, data_loader, distributed=False):
    bn_mean = {}
    bn_var = {}

    forward_model = copy.deepcopy(model)
    for name, m in forward_model.named_modules():
        if isinstance(m, nn.BatchNorm2d):
            if distributed:
                bn_mean[name] = DistributedTensor(name + "#mean")
                bn_var[name] = DistributedTensor(name + "#var")
            else:
                bn_mean[name] = AverageMeter()
                bn_var[name] = AverageMeter()

            def new_forward(bn, mean_est, var_est):
                def lambda_forward(x):
                    batch_mean = (
                        x.mean(0, keepdim=True)
                        .mean(2, keepdim=True)
                        .mean(3, keepdim=True)
                    )  # 1, C, 1, 1
                    batch_var = (x - batch_mean) * (x - batch_mean)
                    batch_var = (
                        batch_var.mean(0, keepdim=True)
                        .mean(2, keepdim=True)
                        .mean(3, keepdim=True)
                    )

                    batch_mean = torch.squeeze(batch_mean)
                    batch_var = torch.squeeze(batch_var)

                    mean_est.update(batch_mean.data, x.size(0))
                    var_est.update(batch_var.data, x.size(0))

                    # bn forward using calculated mean & var
                    _feature_dim = batch_mean.size(0)
                    return F.batch_norm(
                        x,
                        batch_mean,
                        batch_var,
                        bn.weight[:_feature_dim],
                        bn.bias[:_feature_dim],
                        False,
                        0.0,
                        bn.eps,
                    )

                return lambda_forward

            m.forward = new_forward(m, bn_mean[name], bn_var[name])

    if len(bn_mean) == 0:
        # skip if there is no batch normalization layers in the network
        return

    with torch.no_grad():
        DynamicBatchNorm2d.SET_RUNNING_STATISTICS = True
        for images, labels in data_loader:
            images = images.to(get_net_device(forward_model))
            forward_model(images)
        DynamicBatchNorm2d.SET_RUNNING_STATISTICS = False

    for name, m in model.named_modules():
        if name in bn_mean and bn_mean[name].count > 0:
            feature_dim = bn_mean[name].avg.size(0)
            assert isinstance(m, nn.BatchNorm2d)
            m.running_mean.data[:feature_dim].copy_(bn_mean[name].avg)
            m.running_var.data[:feature_dim].copy_(bn_var[name].avg)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from MemSE.fx import fuse, remove_dropout


device = "cuda:0"
ofa_net = OFAResNets().to(device)
print(dataset)
memse_net, ofa_subnet = preprocess_ofa_subnet_for_memse(
    ofa_net, dataset, 32, input_shape, 0.01, 1e6, device=device
)

fused = fuse(ofa_subnet)
fused = remove_dropout(fused)
x, y = next(iter(train_loader))
x, y = x.to(device), y.to(device)
res_prefuse = ofa_subnet(x)
res_ofa = fused(x)
res_memse = memse_net(x)
print(res_prefuse)
print(res_ofa)
print(res_memse)
print(torch.mean(torch.square(res_memse - res_ofa)))
assert torch.all(torch.eq(res_memse, res_ofa))
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /home/sebwood/workspace/MemSE/data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )
# /home/sebwood/miniconda3/envs/memse310/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# opcode         name                           target                         args                                               kwargs
# -------------  -----------------------------  -----------------------------  -------------------------------------------------  ------------------
# placeholder    x                              x                              ()                                                 {}
# call_module    input_stem_0_conv              input_stem.0.conv              (x,)                                               {}
# call_module    input_stem_0_act               input_stem.0.act               (input_stem_0_conv,)                               {}
# call_module    input_stem_1_conv_conv         input_stem.1.conv.conv         (input_stem_0_act,)                                {}
# call_module    input_stem_1_conv_act          input_stem.1.conv.act          (input_stem_1_conv_conv,)                          {}
# call_function  add                            <built-in function add>        (input_stem_1_conv_act, input_stem_0_act)          {}
# call_module    input_stem_2_conv              input_stem.2.conv              (add,)                                             {}
# call_module    input_stem_2_act               input_stem.2.act               (input_stem_2_conv,)                               {}
# call_module    max_pooling                    max_pooling                    (input_stem_2_act,)                                {}
# call_module    blocks_0_downsample_avg_pool   blocks.0.downsample.avg_pool   (max_pooling,)                                     {}
# call_module    blocks_0_downsample_conv       blocks.0.downsample.conv       (blocks_0_downsample_avg_pool,)                    {}
# call_module    blocks_0_conv1_conv            blocks.0.conv1.conv            (max_pooling,)                                     {}
# call_module    blocks_0_conv1_act             blocks.0.conv1.act             (blocks_0_conv1_conv,)                             {}
# call_module    blocks_0_conv2_conv            blocks.0.conv2.conv            (blocks_0_conv1_act,)                              {}
# call_module    blocks_0_conv2_act             blocks.0.conv2.act             (blocks_0_conv2_conv,)                             {}
# call_module    blocks_0_conv3_conv            blocks.0.conv3.conv            (blocks_0_conv2_act,)                              {}
# call_function  add_1                          <built-in function add>        (blocks_0_conv3_conv, blocks_0_downsample_conv)    {}
# call_module    blocks_0_final_act             blocks.0.final_act             (add_1,)                                           {}
# call_module    blocks_1_conv1_conv            blocks.1.conv1.conv            (blocks_0_final_act,)                              {}
# call_module    blocks_1_conv1_act             blocks.1.conv1.act             (blocks_1_conv1_conv,)                             {}
# call_module    blocks_1_conv2_conv            blocks.1.conv2.conv            (blocks_1_conv1_act,)                              {}
# call_module    blocks_1_conv2_act             blocks.1.conv2.act             (blocks_1_conv2_conv,)                             {}
# call_module    blocks_1_conv3_conv            blocks.1.conv3.conv            (blocks_1_conv2_act,)                              {}
# call_function  add_2                          <built-in function add>        (blocks_1_conv3_conv, blocks_0_final_act)          {}
# call_module    blocks_1_final_act             blocks.1.final_act             (add_2,)                                           {}
# call_module    blocks_2_conv1_conv            blocks.2.conv1.conv            (blocks_1_final_act,)                              {}
# call_module    blocks_2_conv1_act             blocks.2.conv1.act             (blocks_2_conv1_conv,)                             {}
# call_module    blocks_2_conv2_conv            blocks.2.conv2.conv            (blocks_2_conv1_act,)                              {}
# call_module    blocks_2_conv2_act             blocks.2.conv2.act             (blocks_2_conv2_conv,)                             {}
# call_module    blocks_2_conv3_conv            blocks.2.conv3.conv            (blocks_2_conv2_act,)                              {}
# call_function  add_3                          <built-in function add>        (blocks_2_conv3_conv, blocks_1_final_act)          {}
# call_module    blocks_2_final_act             blocks.2.final_act             (add_3,)                                           {}
# call_module    blocks_3_conv1_conv            blocks.3.conv1.conv            (blocks_2_final_act,)                              {}
# call_module    blocks_3_conv1_act             blocks.3.conv1.act             (blocks_3_conv1_conv,)                             {}
# call_module    blocks_3_conv2_conv            blocks.3.conv2.conv            (blocks_3_conv1_act,)                              {}
# call_module    blocks_3_conv2_act             blocks.3.conv2.act             (blocks_3_conv2_conv,)                             {}
# call_module    blocks_3_conv3_conv            blocks.3.conv3.conv            (blocks_3_conv2_act,)                              {}
# call_function  add_4                          <built-in function add>        (blocks_3_conv3_conv, blocks_2_final_act)          {}
# call_module    blocks_3_final_act             blocks.3.final_act             (add_4,)                                           {}
# call_module    blocks_4_downsample_avg_pool   blocks.4.downsample.avg_pool   (blocks_3_final_act,)                              {}
# call_module    blocks_4_downsample_conv       blocks.4.downsample.conv       (blocks_4_downsample_avg_pool,)                    {}
# call_module    blocks_4_conv1_conv            blocks.4.conv1.conv            (blocks_3_final_act,)                              {}
# call_module    blocks_4_conv1_act             blocks.4.conv1.act             (blocks_4_conv1_conv,)                             {}
# call_module    blocks_4_conv2_conv            blocks.4.conv2.conv            (blocks_4_conv1_act,)                              {}
# call_module    blocks_4_conv2_act             blocks.4.conv2.act             (blocks_4_conv2_conv,)                             {}
# call_module    blocks_4_conv3_conv            blocks.4.conv3.conv            (blocks_4_conv2_act,)                              {}
# call_function  add_5                          <built-in function add>        (blocks_4_conv3_conv, blocks_4_downsample_conv)    {}
# call_module    blocks_4_final_act             blocks.4.final_act             (add_5,)                                           {}
# call_module    blocks_5_conv1_conv            blocks.5.conv1.conv            (blocks_4_final_act,)                              {}
# call_module    blocks_5_conv1_act             blocks.5.conv1.act             (blocks_5_conv1_conv,)                             {}
# call_module    blocks_5_conv2_conv            blocks.5.conv2.conv            (blocks_5_conv1_act,)                              {}
# call_module    blocks_5_conv2_act             blocks.5.conv2.act             (blocks_5_conv2_conv,)                             {}
# call_module    blocks_5_conv3_conv            blocks.5.conv3.conv            (blocks_5_conv2_act,)                              {}
# call_function  add_6                          <built-in function add>        (blocks_5_conv3_conv, blocks_4_final_act)          {}
# call_module    blocks_5_final_act             blocks.5.final_act             (add_6,)                                           {}
# call_module    blocks_6_conv1_conv            blocks.6.conv1.conv            (blocks_5_final_act,)                              {}
# call_module    blocks_6_conv1_act             blocks.6.conv1.act             (blocks_6_conv1_conv,)                             {}
# call_module    blocks_6_conv2_conv            blocks.6.conv2.conv            (blocks_6_conv1_act,)                              {}
# call_module    blocks_6_conv2_act             blocks.6.conv2.act             (blocks_6_conv2_conv,)                             {}
# call_module    blocks_6_conv3_conv            blocks.6.conv3.conv            (blocks_6_conv2_act,)                              {}
# call_function  add_7                          <built-in function add>        (blocks_6_conv3_conv, blocks_5_final_act)          {}
# call_module    blocks_6_final_act             blocks.6.final_act             (add_7,)                                           {}
# call_module    blocks_7_conv1_conv            blocks.7.conv1.conv            (blocks_6_final_act,)                              {}
# call_module    blocks_7_conv1_act             blocks.7.conv1.act             (blocks_7_conv1_conv,)                             {}
# call_module    blocks_7_conv2_conv            blocks.7.conv2.conv            (blocks_7_conv1_act,)                              {}
# call_module    blocks_7_conv2_act             blocks.7.conv2.act             (blocks_7_conv2_conv,)                             {}
# call_module    blocks_7_conv3_conv            blocks.7.conv3.conv            (blocks_7_conv2_act,)                              {}
# call_function  add_8                          <built-in function add>        (blocks_7_conv3_conv, blocks_6_final_act)          {}
# call_module    blocks_7_final_act             blocks.7.final_act             (add_8,)                                           {}
# call_module    blocks_8_downsample_avg_pool   blocks.8.downsample.avg_pool   (blocks_7_final_act,)                              {}
# call_module    blocks_8_downsample_conv       blocks.8.downsample.conv       (blocks_8_downsample_avg_pool,)                    {}
# call_module    blocks_8_conv1_conv            blocks.8.conv1.conv            (blocks_7_final_act,)                              {}
# call_module    blocks_8_conv1_act             blocks.8.conv1.act             (blocks_8_conv1_conv,)                             {}
# call_module    blocks_8_conv2_conv            blocks.8.conv2.conv            (blocks_8_conv1_act,)                              {}
# call_module    blocks_8_conv2_act             blocks.8.conv2.act             (blocks_8_conv2_conv,)                             {}
# call_module    blocks_8_conv3_conv            blocks.8.conv3.conv            (blocks_8_conv2_act,)                              {}
# call_function  add_9                          <built-in function add>        (blocks_8_conv3_conv, blocks_8_downsample_conv)    {}
# call_module    blocks_8_final_act             blocks.8.final_act             (add_9,)                                           {}
# call_module    blocks_9_conv1_conv            blocks.9.conv1.conv            (blocks_8_final_act,)                              {}
# call_module    blocks_9_conv1_act             blocks.9.conv1.act             (blocks_9_conv1_conv,)                             {}
# call_module    blocks_9_conv2_conv            blocks.9.conv2.conv            (blocks_9_conv1_act,)                              {}
# call_module    blocks_9_conv2_act             blocks.9.conv2.act             (blocks_9_conv2_conv,)                             {}
# call_module    blocks_9_conv3_conv            blocks.9.conv3.conv            (blocks_9_conv2_act,)                              {}
# call_function  add_10                         <built-in function add>        (blocks_9_conv3_conv, blocks_8_final_act)          {}
# call_module    blocks_9_final_act             blocks.9.final_act             (add_10,)                                          {}
# call_module    blocks_10_conv1_conv           blocks.10.conv1.conv           (blocks_9_final_act,)                              {}
# call_module    blocks_10_conv1_act            blocks.10.conv1.act            (blocks_10_conv1_conv,)                            {}
# call_module    blocks_10_conv2_conv           blocks.10.conv2.conv           (blocks_10_conv1_act,)                             {}
# call_module    blocks_10_conv2_act            blocks.10.conv2.act            (blocks_10_conv2_conv,)                            {}
# call_module    blocks_10_conv3_conv           blocks.10.conv3.conv           (blocks_10_conv2_act,)                             {}
# call_function  add_11                         <built-in function add>        (blocks_10_conv3_conv, blocks_9_final_act)         {}
# call_module    blocks_10_final_act            blocks.10.final_act            (add_11,)                                          {}
# call_module    blocks_11_conv1_conv           blocks.11.conv1.conv           (blocks_10_final_act,)                             {}
# call_module    blocks_11_conv1_act            blocks.11.conv1.act            (blocks_11_conv1_conv,)                            {}
# call_module    blocks_11_conv2_conv           blocks.11.conv2.conv           (blocks_11_conv1_act,)                             {}
# call_module    blocks_11_conv2_act            blocks.11.conv2.act            (blocks_11_conv2_conv,)                            {}
# call_module    blocks_11_conv3_conv           blocks.11.conv3.conv           (blocks_11_conv2_act,)                             {}
# call_function  add_12                         <built-in function add>        (blocks_11_conv3_conv, blocks_10_final_act)        {}
# call_module    blocks_11_final_act            blocks.11.final_act            (add_12,)                                          {}
# call_module    blocks_12_conv1_conv           blocks.12.conv1.conv           (blocks_11_final_act,)                             {}
# call_module    blocks_12_conv1_act            blocks.12.conv1.act            (blocks_12_conv1_conv,)                            {}
# call_module    blocks_12_conv2_conv           blocks.12.conv2.conv           (blocks_12_conv1_act,)                             {}
# call_module    blocks_12_conv2_act            blocks.12.conv2.act            (blocks_12_conv2_conv,)                            {}
# call_module    blocks_12_conv3_conv           blocks.12.conv3.conv           (blocks_12_conv2_act,)                             {}
# call_function  add_13                         <built-in function add>        (blocks_12_conv3_conv, blocks_11_final_act)        {}
# call_module    blocks_12_final_act            blocks.12.final_act            (add_13,)                                          {}
# call_module    blocks_13_conv1_conv           blocks.13.conv1.conv           (blocks_12_final_act,)                             {}
# call_module    blocks_13_conv1_act            blocks.13.conv1.act            (blocks_13_conv1_conv,)                            {}
# call_module    blocks_13_conv2_conv           blocks.13.conv2.conv           (blocks_13_conv1_act,)                             {}
# call_module    blocks_13_conv2_act            blocks.13.conv2.act            (blocks_13_conv2_conv,)                            {}
# call_module    blocks_13_conv3_conv           blocks.13.conv3.conv           (blocks_13_conv2_act,)                             {}
# call_function  add_14                         <built-in function add>        (blocks_13_conv3_conv, blocks_12_final_act)        {}
# call_module    blocks_13_final_act            blocks.13.final_act            (add_14,)                                          {}
# call_module    blocks_14_downsample_avg_pool  blocks.14.downsample.avg_pool  (blocks_13_final_act,)                             {}
# call_module    blocks_14_downsample_conv      blocks.14.downsample.conv      (blocks_14_downsample_avg_pool,)                   {}
# call_module    blocks_14_conv1_conv           blocks.14.conv1.conv           (blocks_13_final_act,)                             {}
# call_module    blocks_14_conv1_act            blocks.14.conv1.act            (blocks_14_conv1_conv,)                            {}
# call_module    blocks_14_conv2_conv           blocks.14.conv2.conv           (blocks_14_conv1_act,)                             {}
# call_module    blocks_14_conv2_act            blocks.14.conv2.act            (blocks_14_conv2_conv,)                            {}
# call_module    blocks_14_conv3_conv           blocks.14.conv3.conv           (blocks_14_conv2_act,)                             {}
# call_function  add_15                         <built-in function add>        (blocks_14_conv3_conv, blocks_14_downsample_conv)  {}
# call_module    blocks_14_final_act            blocks.14.final_act            (add_15,)                                          {}
# call_module    blocks_15_conv1_conv           blocks.15.conv1.conv           (blocks_14_final_act,)                             {}
# call_module    blocks_15_conv1_act            blocks.15.conv1.act            (blocks_15_conv1_conv,)                            {}
# call_module    blocks_15_conv2_conv           blocks.15.conv2.conv           (blocks_15_conv1_act,)                             {}
# call_module    blocks_15_conv2_act            blocks.15.conv2.act            (blocks_15_conv2_conv,)                            {}
# call_module    blocks_15_conv3_conv           blocks.15.conv3.conv           (blocks_15_conv2_act,)                             {}
# call_function  add_16                         <built-in function add>        (blocks_15_conv3_conv, blocks_14_final_act)        {}
# call_module    blocks_15_final_act            blocks.15.final_act            (add_16,)                                          {}
# call_module    blocks_16_conv1_conv           blocks.16.conv1.conv           (blocks_15_final_act,)                             {}
# call_module    blocks_16_conv1_act            blocks.16.conv1.act            (blocks_16_conv1_conv,)                            {}
# call_module    blocks_16_conv2_conv           blocks.16.conv2.conv           (blocks_16_conv1_act,)                             {}
# call_module    blocks_16_conv2_act            blocks.16.conv2.act            (blocks_16_conv2_conv,)                            {}
# call_module    blocks_16_conv3_conv           blocks.16.conv3.conv           (blocks_16_conv2_act,)                             {}
# call_function  add_17                         <built-in function add>        (blocks_16_conv3_conv, blocks_15_final_act)        {}
# call_module    blocks_16_final_act            blocks.16.final_act            (add_17,)                                          {}
# call_module    blocks_17_conv1_conv           blocks.17.conv1.conv           (blocks_16_final_act,)                             {}
# call_module    blocks_17_conv1_act            blocks.17.conv1.act            (blocks_17_conv1_conv,)                            {}
# call_module    blocks_17_conv2_conv           blocks.17.conv2.conv           (blocks_17_conv1_act,)                             {}
# call_module    blocks_17_conv2_act            blocks.17.conv2.act            (blocks_17_conv2_conv,)                            {}
# call_module    blocks_17_conv3_conv           blocks.17.conv3.conv           (blocks_17_conv2_act,)                             {}
# call_function  add_18                         <built-in function add>        (blocks_17_conv3_conv, blocks_16_final_act)        {}
# call_module    blocks_17_final_act            blocks.17.final_act            (add_18,)                                          {}
# call_method    mean                           mean                           (blocks_17_final_act, 3)                           {'keepdim': False}
# call_method    mean_1                         mean                           (mean, 2)                                          {'keepdim': False}
# call_module    classifier_linear              classifier.linear              (mean_1,)                                          {}
# output         output                         output                         (classifier_linear,)                               {}
# opcode         name                           target                             args                                               kwargs
# -------------  -----------------------------  ---------------------------------  -------------------------------------------------  ------------------
# placeholder    x                              x                                  ()                                                 {}
# call_module    input_stem_0_conv              input_stem.0.conv                  (x,)                                               {}
# call_module    input_stem_0_act               input_stem.0.act                   (input_stem_0_conv,)                               {}
# call_module    input_stem_1_conv_conv         input_stem.1.conv.conv             (input_stem_0_act,)                                {}
# call_module    input_stem_1_conv_act          input_stem.1.conv.act              (input_stem_1_conv_conv,)                          {}
# call_function  add_19                         <function Add at 0x7fa180eaf5b0>   (input_stem_1_conv_act, input_stem_0_act)          {}
# call_module    input_stem_2_conv              input_stem.2.conv                  (add_19,)                                          {}
# call_module    input_stem_2_act               input_stem.2.act                   (input_stem_2_conv,)                               {}
# call_module    max_pooling                    max_pooling                        (input_stem_2_act,)                                {}
# call_module    blocks_0_downsample_avg_pool   blocks.0.downsample.avg_pool       (max_pooling,)                                     {}
# call_module    blocks_0_downsample_conv       blocks.0.downsample.conv           (blocks_0_downsample_avg_pool,)                    {}
# call_module    blocks_0_conv1_conv            blocks.0.conv1.conv                (max_pooling,)                                     {}
# call_module    blocks_0_conv1_act             blocks.0.conv1.act                 (blocks_0_conv1_conv,)                             {}
# call_module    blocks_0_conv2_conv            blocks.0.conv2.conv                (blocks_0_conv1_act,)                              {}
# call_module    blocks_0_conv2_act             blocks.0.conv2.act                 (blocks_0_conv2_conv,)                             {}
# call_module    blocks_0_conv3_conv            blocks.0.conv3.conv                (blocks_0_conv2_act,)                              {}
# call_function  add_20                         <function Add at 0x7fa180eaf5b0>   (blocks_0_conv3_conv, blocks_0_downsample_conv)    {}
# call_module    blocks_0_final_act             blocks.0.final_act                 (add_20,)                                          {}
# call_module    blocks_1_conv1_conv            blocks.1.conv1.conv                (blocks_0_final_act,)                              {}
# call_module    blocks_1_conv1_act             blocks.1.conv1.act                 (blocks_1_conv1_conv,)                             {}
# call_module    blocks_1_conv2_conv            blocks.1.conv2.conv                (blocks_1_conv1_act,)                              {}
# call_module    blocks_1_conv2_act             blocks.1.conv2.act                 (blocks_1_conv2_conv,)                             {}
# call_module    blocks_1_conv3_conv            blocks.1.conv3.conv                (blocks_1_conv2_act,)                              {}
# call_function  add_21                         <function Add at 0x7fa180eaf5b0>   (blocks_1_conv3_conv, blocks_0_final_act)          {}
# call_module    blocks_1_final_act             blocks.1.final_act                 (add_21,)                                          {}
# call_module    blocks_2_conv1_conv            blocks.2.conv1.conv                (blocks_1_final_act,)                              {}
# call_module    blocks_2_conv1_act             blocks.2.conv1.act                 (blocks_2_conv1_conv,)                             {}
# call_module    blocks_2_conv2_conv            blocks.2.conv2.conv                (blocks_2_conv1_act,)                              {}
# call_module    blocks_2_conv2_act             blocks.2.conv2.act                 (blocks_2_conv2_conv,)                             {}
# call_module    blocks_2_conv3_conv            blocks.2.conv3.conv                (blocks_2_conv2_act,)                              {}
# call_function  add_22                         <function Add at 0x7fa180eaf5b0>   (blocks_2_conv3_conv, blocks_1_final_act)          {}
# call_module    blocks_2_final_act             blocks.2.final_act                 (add_22,)                                          {}
# call_module    blocks_3_conv1_conv            blocks.3.conv1.conv                (blocks_2_final_act,)                              {}
# call_module    blocks_3_conv1_act             blocks.3.conv1.act                 (blocks_3_conv1_conv,)                             {}
# call_module    blocks_3_conv2_conv            blocks.3.conv2.conv                (blocks_3_conv1_act,)                              {}
# call_module    blocks_3_conv2_act             blocks.3.conv2.act                 (blocks_3_conv2_conv,)                             {}
# call_module    blocks_3_conv3_conv            blocks.3.conv3.conv                (blocks_3_conv2_act,)                              {}
# call_function  add_23                         <function Add at 0x7fa180eaf5b0>   (blocks_3_conv3_conv, blocks_2_final_act)          {}
# call_module    blocks_3_final_act             blocks.3.final_act                 (add_23,)                                          {}
# call_module    blocks_4_downsample_avg_pool   blocks.4.downsample.avg_pool       (blocks_3_final_act,)                              {}
# call_module    blocks_4_downsample_conv       blocks.4.downsample.conv           (blocks_4_downsample_avg_pool,)                    {}
# call_module    blocks_4_conv1_conv            blocks.4.conv1.conv                (blocks_3_final_act,)                              {}
# call_module    blocks_4_conv1_act             blocks.4.conv1.act                 (blocks_4_conv1_conv,)                             {}
# call_module    blocks_4_conv2_conv            blocks.4.conv2.conv                (blocks_4_conv1_act,)                              {}
# call_module    blocks_4_conv2_act             blocks.4.conv2.act                 (blocks_4_conv2_conv,)                             {}
# call_module    blocks_4_conv3_conv            blocks.4.conv3.conv                (blocks_4_conv2_act,)                              {}
# call_function  add_24                         <function Add at 0x7fa180eaf5b0>   (blocks_4_conv3_conv, blocks_4_downsample_conv)    {}
# call_module    blocks_4_final_act             blocks.4.final_act                 (add_24,)                                          {}
# call_module    blocks_5_conv1_conv            blocks.5.conv1.conv                (blocks_4_final_act,)                              {}
# call_module    blocks_5_conv1_act             blocks.5.conv1.act                 (blocks_5_conv1_conv,)                             {}
# call_module    blocks_5_conv2_conv            blocks.5.conv2.conv                (blocks_5_conv1_act,)                              {}
# call_module    blocks_5_conv2_act             blocks.5.conv2.act                 (blocks_5_conv2_conv,)                             {}
# call_module    blocks_5_conv3_conv            blocks.5.conv3.conv                (blocks_5_conv2_act,)                              {}
# call_function  add_25                         <function Add at 0x7fa180eaf5b0>   (blocks_5_conv3_conv, blocks_4_final_act)          {}
# call_module    blocks_5_final_act             blocks.5.final_act                 (add_25,)                                          {}
# call_module    blocks_6_conv1_conv            blocks.6.conv1.conv                (blocks_5_final_act,)                              {}
# call_module    blocks_6_conv1_act             blocks.6.conv1.act                 (blocks_6_conv1_conv,)                             {}
# call_module    blocks_6_conv2_conv            blocks.6.conv2.conv                (blocks_6_conv1_act,)                              {}
# call_module    blocks_6_conv2_act             blocks.6.conv2.act                 (blocks_6_conv2_conv,)                             {}
# call_module    blocks_6_conv3_conv            blocks.6.conv3.conv                (blocks_6_conv2_act,)                              {}
# call_function  add_26                         <function Add at 0x7fa180eaf5b0>   (blocks_6_conv3_conv, blocks_5_final_act)          {}
# call_module    blocks_6_final_act             blocks.6.final_act                 (add_26,)                                          {}
# call_module    blocks_7_conv1_conv            blocks.7.conv1.conv                (blocks_6_final_act,)                              {}
# call_module    blocks_7_conv1_act             blocks.7.conv1.act                 (blocks_7_conv1_conv,)                             {}
# call_module    blocks_7_conv2_conv            blocks.7.conv2.conv                (blocks_7_conv1_act,)                              {}
# call_module    blocks_7_conv2_act             blocks.7.conv2.act                 (blocks_7_conv2_conv,)                             {}
# call_module    blocks_7_conv3_conv            blocks.7.conv3.conv                (blocks_7_conv2_act,)                              {}
# call_function  add_27                         <function Add at 0x7fa180eaf5b0>   (blocks_7_conv3_conv, blocks_6_final_act)          {}
# call_module    blocks_7_final_act             blocks.7.final_act                 (add_27,)                                          {}
# call_module    blocks_8_downsample_avg_pool   blocks.8.downsample.avg_pool       (blocks_7_final_act,)                              {}
# call_module    blocks_8_downsample_conv       blocks.8.downsample.conv           (blocks_8_downsample_avg_pool,)                    {}
# call_module    blocks_8_conv1_conv            blocks.8.conv1.conv                (blocks_7_final_act,)                              {}
# call_module    blocks_8_conv1_act             blocks.8.conv1.act                 (blocks_8_conv1_conv,)                             {}
# call_module    blocks_8_conv2_conv            blocks.8.conv2.conv                (blocks_8_conv1_act,)                              {}
# call_module    blocks_8_conv2_act             blocks.8.conv2.act                 (blocks_8_conv2_conv,)                             {}
# call_module    blocks_8_conv3_conv            blocks.8.conv3.conv                (blocks_8_conv2_act,)                              {}
# call_function  add_28                         <function Add at 0x7fa180eaf5b0>   (blocks_8_conv3_conv, blocks_8_downsample_conv)    {}
# call_module    blocks_8_final_act             blocks.8.final_act                 (add_28,)                                          {}
# call_module    blocks_9_conv1_conv            blocks.9.conv1.conv                (blocks_8_final_act,)                              {}
# call_module    blocks_9_conv1_act             blocks.9.conv1.act                 (blocks_9_conv1_conv,)                             {}
# call_module    blocks_9_conv2_conv            blocks.9.conv2.conv                (blocks_9_conv1_act,)                              {}
# call_module    blocks_9_conv2_act             blocks.9.conv2.act                 (blocks_9_conv2_conv,)                             {}
# call_module    blocks_9_conv3_conv            blocks.9.conv3.conv                (blocks_9_conv2_act,)                              {}
# call_function  add_29                         <function Add at 0x7fa180eaf5b0>   (blocks_9_conv3_conv, blocks_8_final_act)          {}
# call_module    blocks_9_final_act             blocks.9.final_act                 (add_29,)                                          {}
# call_module    blocks_10_conv1_conv           blocks.10.conv1.conv               (blocks_9_final_act,)                              {}
# call_module    blocks_10_conv1_act            blocks.10.conv1.act                (blocks_10_conv1_conv,)                            {}
# call_module    blocks_10_conv2_conv           blocks.10.conv2.conv               (blocks_10_conv1_act,)                             {}
# call_module    blocks_10_conv2_act            blocks.10.conv2.act                (blocks_10_conv2_conv,)                            {}
# call_module    blocks_10_conv3_conv           blocks.10.conv3.conv               (blocks_10_conv2_act,)                             {}
# call_function  add_30                         <function Add at 0x7fa180eaf5b0>   (blocks_10_conv3_conv, blocks_9_final_act)         {}
# call_module    blocks_10_final_act            blocks.10.final_act                (add_30,)                                          {}
# call_module    blocks_11_conv1_conv           blocks.11.conv1.conv               (blocks_10_final_act,)                             {}
# call_module    blocks_11_conv1_act            blocks.11.conv1.act                (blocks_11_conv1_conv,)                            {}
# call_module    blocks_11_conv2_conv           blocks.11.conv2.conv               (blocks_11_conv1_act,)                             {}
# call_module    blocks_11_conv2_act            blocks.11.conv2.act                (blocks_11_conv2_conv,)                            {}
# call_module    blocks_11_conv3_conv           blocks.11.conv3.conv               (blocks_11_conv2_act,)                             {}
# call_function  add_31                         <function Add at 0x7fa180eaf5b0>   (blocks_11_conv3_conv, blocks_10_final_act)        {}
# call_module    blocks_11_final_act            blocks.11.final_act                (add_31,)                                          {}
# call_module    blocks_12_conv1_conv           blocks.12.conv1.conv               (blocks_11_final_act,)                             {}
# call_module    blocks_12_conv1_act            blocks.12.conv1.act                (blocks_12_conv1_conv,)                            {}
# call_module    blocks_12_conv2_conv           blocks.12.conv2.conv               (blocks_12_conv1_act,)                             {}
# call_module    blocks_12_conv2_act            blocks.12.conv2.act                (blocks_12_conv2_conv,)                            {}
# call_module    blocks_12_conv3_conv           blocks.12.conv3.conv               (blocks_12_conv2_act,)                             {}
# call_function  add_32                         <function Add at 0x7fa180eaf5b0>   (blocks_12_conv3_conv, blocks_11_final_act)        {}
# call_module    blocks_12_final_act            blocks.12.final_act                (add_32,)                                          {}
# call_module    blocks_13_conv1_conv           blocks.13.conv1.conv               (blocks_12_final_act,)                             {}
# call_module    blocks_13_conv1_act            blocks.13.conv1.act                (blocks_13_conv1_conv,)                            {}
# call_module    blocks_13_conv2_conv           blocks.13.conv2.conv               (blocks_13_conv1_act,)                             {}
# call_module    blocks_13_conv2_act            blocks.13.conv2.act                (blocks_13_conv2_conv,)                            {}
# call_module    blocks_13_conv3_conv           blocks.13.conv3.conv               (blocks_13_conv2_act,)                             {}
# call_function  add_33                         <function Add at 0x7fa180eaf5b0>   (blocks_13_conv3_conv, blocks_12_final_act)        {}
# call_module    blocks_13_final_act            blocks.13.final_act                (add_33,)                                          {}
# call_module    blocks_14_downsample_avg_pool  blocks.14.downsample.avg_pool      (blocks_13_final_act,)                             {}
# call_module    blocks_14_downsample_conv      blocks.14.downsample.conv          (blocks_14_downsample_avg_pool,)                   {}
# call_module    blocks_14_conv1_conv           blocks.14.conv1.conv               (blocks_13_final_act,)                             {}
# call_module    blocks_14_conv1_act            blocks.14.conv1.act                (blocks_14_conv1_conv,)                            {}
# call_module    blocks_14_conv2_conv           blocks.14.conv2.conv               (blocks_14_conv1_act,)                             {}
# call_module    blocks_14_conv2_act            blocks.14.conv2.act                (blocks_14_conv2_conv,)                            {}
# call_module    blocks_14_conv3_conv           blocks.14.conv3.conv               (blocks_14_conv2_act,)                             {}
# call_function  add_34                         <function Add at 0x7fa180eaf5b0>   (blocks_14_conv3_conv, blocks_14_downsample_conv)  {}
# call_module    blocks_14_final_act            blocks.14.final_act                (add_34,)                                          {}
# call_module    blocks_15_conv1_conv           blocks.15.conv1.conv               (blocks_14_final_act,)                             {}
# call_module    blocks_15_conv1_act            blocks.15.conv1.act                (blocks_15_conv1_conv,)                            {}
# call_module    blocks_15_conv2_conv           blocks.15.conv2.conv               (blocks_15_conv1_act,)                             {}
# call_module    blocks_15_conv2_act            blocks.15.conv2.act                (blocks_15_conv2_conv,)                            {}
# call_module    blocks_15_conv3_conv           blocks.15.conv3.conv               (blocks_15_conv2_act,)                             {}
# call_function  add_35                         <function Add at 0x7fa180eaf5b0>   (blocks_15_conv3_conv, blocks_14_final_act)        {}
# call_module    blocks_15_final_act            blocks.15.final_act                (add_35,)                                          {}
# call_module    blocks_16_conv1_conv           blocks.16.conv1.conv               (blocks_15_final_act,)                             {}
# call_module    blocks_16_conv1_act            blocks.16.conv1.act                (blocks_16_conv1_conv,)                            {}
# call_module    blocks_16_conv2_conv           blocks.16.conv2.conv               (blocks_16_conv1_act,)                             {}
# call_module    blocks_16_conv2_act            blocks.16.conv2.act                (blocks_16_conv2_conv,)                            {}
# call_module    blocks_16_conv3_conv           blocks.16.conv3.conv               (blocks_16_conv2_act,)                             {}
# call_function  add_36                         <function Add at 0x7fa180eaf5b0>   (blocks_16_conv3_conv, blocks_15_final_act)        {}
# call_module    blocks_16_final_act            blocks.16.final_act                (add_36,)                                          {}
# call_module    blocks_17_conv1_conv           blocks.17.conv1.conv               (blocks_16_final_act,)                             {}
# call_module    blocks_17_conv1_act            blocks.17.conv1.act                (blocks_17_conv1_conv,)                            {}
# call_module    blocks_17_conv2_conv           blocks.17.conv2.conv               (blocks_17_conv1_act,)                             {}
# call_module    blocks_17_conv2_act            blocks.17.conv2.act                (blocks_17_conv2_conv,)                            {}
# call_module    blocks_17_conv3_conv           blocks.17.conv3.conv               (blocks_17_conv2_act,)                             {}
# call_function  add_37                         <function Add at 0x7fa180eaf5b0>   (blocks_17_conv3_conv, blocks_16_final_act)        {}
# call_module    blocks_17_final_act            blocks.17.final_act                (add_37,)                                          {}
# call_function  mean_2                         <function Mean at 0x7fa180eaf9a0>  (blocks_17_final_act, 3)                           {'keepdim': False}
# call_function  mean_3                         <function Mean at 0x7fa180eaf9a0>  (mean_2, 2)                                        {'keepdim': False}
# call_module    classifier_linear              classifier.linear                  (mean_3,)                                          {}
# output         output                         output                             (classifier_linear,)                               {}
# tensor([[-3.5258, -1.8945,  1.5328,  ...,  0.1099, -0.2560,  3.4851],
#         [-0.8918, -0.4524,  0.5937,  ...,  0.0311, -0.6630,  0.0697],
#         [-1.6238, -1.0685,  0.9568,  ...,  1.2497,  0.1697,  0.6449],
#         ...,
#         [-1.9836, -0.1000,  0.7323,  ..., -0.0411, -0.5271,  0.3673],
#         [-1.0458, -1.4211,  0.6168,  ..., -0.2072,  0.3806, -0.3419],
#         [-0.4205,  0.5366,  0.9745,  ...,  0.2996, -1.4871,  0.1500]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-4.9043, -3.3159,  5.6981,  ..., -2.6635,  0.6648,  7.7697],
#         [-0.9083, -0.6914,  0.1481,  ..., -0.2289, -0.2191,  0.2864],
#         [-1.2313, -0.2000,  0.2838,  ..., -0.1197, -1.0413,  1.8279],
#         ...,
#         [-0.8132, -0.5675,  1.6780,  ...,  0.1113, -0.4328, -0.1511],
#         [-1.2867,  0.1928,  1.2405,  ...,  1.1133,  0.4197, -0.8787],
#         [-0.8126, -0.5173,  0.6311,  ...,  0.8347, -0.4647, -0.4172]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-4.9043, -3.3159,  5.6981,  ..., -2.6635,  0.6648,  7.7697],
#         [-0.9083, -0.6914,  0.1481,  ..., -0.2289, -0.2191,  0.2864],
#         [-1.2313, -0.2000,  0.2838,  ..., -0.1197, -1.0413,  1.8279],
#         ...,
#         [-0.8132, -0.5675,  1.6780,  ...,  0.1113, -0.4328, -0.1511],
#         [-1.2867,  0.1928,  1.2405,  ...,  1.1133,  0.4197, -0.8787],
#         [-0.8126, -0.5173,  0.6311,  ...,  0.8347, -0.4647, -0.4172]],
#        device='cuda:0', grad_fn=<MmBackward0>)
# tensor(3.0656e-13, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 22
#      20 print(res_memse)
#      21 print(torch.mean(torch.square(res_memse - res_ofa)))
# ---> 22 assert torch.all(torch.eq(res_memse, res_ofa))
#
# AssertionError:
