# %%
from MemSE.mse_functions import dd_softplus, sigmoid_coefs

import torch
import matplotlib.pyplot as plt

ten = torch.linspace(-5, 5, 100)
_, _, res = dd_softplus(ten, order=16)

fig, ax = plt.subplots(4, 4, figsize=(12,12))
for i in range(16):
    ax[int(i / 4), int(i % 4)].plot(ten.numpy(), res[i], 'k-', label=f'{i=}')
    ax[int(i / 4), int(i % 4)].legend()
plt.show()
# Out:
# [pyKeOps]: Warning, no cuda detected. Switching to cpu only.

# %%
sigmoid_coefs(5)
# Out:
# array([   1,  -31,  180, -390,  360, -120])

# %%
sigmoid_coefs(10)
# Out:
# array([        1,     -1023,     57002,   -874500,   5921520, -21538440,
#         46070640, -59875200,  46569600, -19958400,   3628800])
